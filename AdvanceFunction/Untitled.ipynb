# %%
import pandas as pd

# %%
df1=pd.read_csv('emp_info.csv')

# %%
df2=pd.read_csv('emp_salaries.csv')

# %%
df1
# Out:
#    eno    ename
# 0    1    lavan
# 1    2     ramu
# 2    3     gopi
# 3    4   rajesh
# 4    5  kavitha

# %%
df2
# Out:
#    eno  salary
# 0    1    1000
# 1    2    2000
# 2    3     500
# 3    5    5000
# 4    6     300
# 5    7     100

# %%
df1.merge(df2)
# Out:
#    eno    ename  salary
# 0    1    lavan    1000
# 1    2     ramu    2000
# 2    3     gopi     500
# 3    5  kavitha    5000

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
#    eno    ename  salary
# 0    1    lavan    1000
# 1    2     ramu    2000
# 2    3     gopi     500
# 3    5  kavitha    5000

# %%
df1.merge(df2,on='eno',how='left')
# Out:
#    eno    ename  salary
# 0    1    lavan  1000.0
# 1    2     ramu  2000.0
# 2    3     gopi   500.0
# 3    4   rajesh     NaN
# 4    5  kavitha  5000.0

# %%
df1.merge(df2,on='eno',how='right')
# Out:
#    eno    ename  salary
# 0    1    lavan    1000
# 1    2     ramu    2000
# 2    3     gopi     500
# 3    5  kavitha    5000
# 4    6      NaN     300
# 5    7      NaN     100

# %%
df1.merge(df2,on='eno',how='outer')
# Out:
#    eno    ename  salary
# 0    1    lavan  1000.0
# 1    2     ramu  2000.0
# 2    3     gopi   500.0
# 3    4   rajesh     NaN
# 4    5  kavitha  5000.0
# 5    6      NaN   300.0
# 6    7      NaN   100.0

# %%
df1.merge(df2,left_on='eno',right_on='eno')
# Out:
#    eno    ename  salary
# 0    1    lavan    1000
# 1    2     ramu    2000
# 2    3     gopi     500
# 3    5  kavitha    5000
