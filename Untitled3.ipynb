# %%
import pandas as pd

# %%
df=pd.read_csv('employees.csv')

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777   7-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888   7-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080   7-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181   7-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
grpby_df=df.groupby('JOB_ID')

# %%
grpby_df

# %%
grpby_df['SALARY'].sum()
# Out:
# JOB_ID
# AC_ACCOUNT     8300
# AC_MGR        12008
# AD_ASST        4400
# AD_PRES       24000
# AD_VP         34000
# FI_ACCOUNT    39600
# FI_MGR        12008
# HR_REP         6500
# IT_PROG       28800
# MK_MAN        13000
# MK_REP         6000
# PR_REP        10000
# PU_CLERK      13900
# PU_MAN        11000
# SH_CLERK       5200
# ST_CLERK      44000
# ST_MAN        36400
# Name: SALARY, dtype: int64

# %%
df.groupby('JOB_ID').count()
# Out:
#             EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  \
# JOB_ID
# AC_ACCOUNT            1           1          1      1             1
# AC_MGR                1           1          1      1             1
# AD_ASST               1           1          1      1             1
# AD_PRES               1           1          1      1             1
# AD_VP                 2           2          2      2             2
# FI_ACCOUNT            5           5          5      5             5
# FI_MGR                1           1          1      1             1
# HR_REP                1           1          1      1             1
# IT_PROG               5           5          5      5             5
# MK_MAN                1           1          1      1             1
# MK_REP                1           1          1      1             1
# PR_REP                1           1          1      1             1
# PU_CLERK              5           5          5      5             5
# ...

# %%
df.groupby('JOB_ID')['JOB_ID'].count()
# Out:
# JOB_ID
# AC_ACCOUNT     1
# AC_MGR         1
# AD_ASST        1
# AD_PRES        1
# AD_VP          2
# FI_ACCOUNT     5
# FI_MGR         1
# HR_REP         1
# IT_PROG        5
# MK_MAN         1
# MK_REP         1
# PR_REP         1
# PU_CLERK       5
# PU_MAN         1
# SH_CLERK       2
# ST_CLERK      16
# ST_MAN         5
# Name: JOB_ID, dtype: int64

# %%
df.groupby('MANAGER_ID')['MANAGER_ID'].count()
# Out:
# MANAGER_ID
#  -     1
# 100    9
# 101    5
# 102    1
# 103    4
# 108    5
# 114    5
# 120    4
# 121    4
# 122    4
# 123    4
# 124    2
# 201    1
# 205    1
# Name: MANAGER_ID, dtype: int64

# %%
df.groupby('MANAGER_ID')['SALARY'].sum()
# Out:
# MANAGER_ID
#  -     24000
# 100    94400
# 101    44916
# 102     9000
# 103    19800
# 108    39600
# 114    13900
# 120    10500
# 121    10700
# 122    10800
# 123    12000
# 124     5200
# 201     6000
# 205     8300
# Name: SALARY, dtype: int64

# %%
df.groupby('MANAGER_ID')['SALARY'].mean()
# Out:
# MANAGER_ID
#  -     24000.000000
# 100    10488.888889
# 101     8983.200000
# 102     9000.000000
# 103     4950.000000
# 108     7920.000000
# 114     2780.000000
# 120     2625.000000
# 121     2675.000000
# 122     2700.000000
# 123     3000.000000
# 124     2600.000000
# 201     6000.000000
# 205     8300.000000
# Name: SALARY, dtype: float64

# %%
type('grpby_df')
# Out:
# str

# %%
type(grpby_df)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy
