# %%
import pandas as pd

# %%
map1 = {"eno":[1,2,3,4,5],"ename":["A","B","C","D","E"],"grade":["g1","g2","g3","g4","g5"]}

# %%
map1
# Out:
# {'eno': [1, 2, 3, 4, 5],
#  'ename': ['A', 'B', 'C', 'D', 'E'],
#  'grade': ['g1', 'g2', 'g3', 'g4', 'g5']}

# %%
df=pd.DataFrame(map1)

# %%
df
# Out:
#    eno ename grade
# 0    1     A    g1
# 1    2     B    g2
# 2    3     C    g3
# 3    4     D    g4
# 4    5     E    g5

# %%
df.to_csv('emp1.csv',index=False)

# %%
df['ename']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: ename, dtype: object

# %%
type(df['ename'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['eno','grade']]
# Out:
#    eno grade
# 0    1    g1
# 1    2    g2
# 2    3    g3
# 3    4    g4
# 4    5    g5

# %%
type(df[['eno','grade']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=pd.read_csv('emp1.csv')

# %%
df1
# Out:
#    eno ename grade
# 0    1     A    g1
# 1    2     B    g2
# 2    3     C    g3
# 3    4     D    g4
# 4    5     E    g5

# %%
df1=pd.read_csv('emp1.csv',delimiter=',')

# %%
df1
# Out:
#    eno ename grade
# 0    1     A    g1
# 1    2     B    g2
# 2    3     C    g3
# 3    4     D    g4
# 4    5     E    g5

# %%
df1=pd.read_csv('emp1.csv',delimiter=',',usecols=[0,1])

# %%
df1
# Out:
#    eno ename
# 0    1     A
# 1    2     B
# 2    3     C
# 3    4     D
# 4    5     E

# %%
df2=pd.read_csv('MW-NIFTY-50-15-Aug-2024.csv')

# %%
df2
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1          TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2      HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3        TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4         INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5          M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6        WIPRO     493.00     496.85     490.45         490.50     495.70
# 7         BPCL     321.70     327.45     320.65         321.70     325.10
# 8   BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9   TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# 10        LTIM   5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# 11        SBIN     800.95     809.15     800.40         797.55     803.20
# ...

# %%
df2.head(10)
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1         TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2     HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3       TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4        INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5         M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6       WIPRO     493.00     496.85     490.45         490.50     495.70
# 7        BPCL     321.70     327.45     320.65         321.70     325.10
# 8  BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9  TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
#
#    CHNG \n  %CHNG \n VOLUME \n(shares) VALUE \n (₹ Crores)   52W H \n  \
# 0     4.75      0.02      30,32,54,705           27,834.44  25,078.30
# ...

# %%
df2.tail(10)
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 41  ADANIPORTS   1,488.00   1,488.00   1,452.00       1,483.45   1,460.00
# 42   TATASTEEL     149.90     149.90     142.35         148.88     146.50
# 43    ADANIENT   3,085.70   3,085.70   3,027.75       3,092.20   3,036.25
# 44        ONGC     335.85     336.50     326.80         335.90     329.80
# 45    JSWSTEEL     911.95     911.95     885.40         907.85     890.00
# 46     DRREDDY   6,955.00   6,962.00   6,792.50       6,948.40   6,800.00
# 47  ULTRACEMCO  11,200.00  11,200.00  10,963.10      11,271.20  11,006.55
# 48   COALINDIA     522.90     527.90     499.05         521.75     506.10
# 49  HEROMOTOCO   5,280.00   5,297.60   4,991.00       5,245.50   5,079.00
# 50    DIVISLAB   4,848.00   4,848.00   4,642.05       4,861.80   4,666.00
#
#     CHNG \n  %CHNG \n VOLUME \n(shares) VALUE \n (₹ Crores)   52W H \n  \
# 41   -23.45     -1.58         26,48,057              387.17   1,621.40
# ...

# %%
df2.head(10).tail(1)
# Out:
#     SYMBOL \n   OPEN \n   HIGH \n    LOW \n PREV. CLOSE \n    LTP \n  CHNG \n  \
# 9  TATAMOTORS  1,057.00  1,067.05  1,047.00       1,053.45  1,062.85      9.4
#
#    %CHNG \n VOLUME \n(shares) VALUE \n (₹ Crores)  52W H \n 52W L \n  \
# 9      0.89         82,11,830              869.81  1,179.00   593.30
#
#    30 D   %CHNG \n  365 D % CHNG \n 14-Aug-2023
# 9              3.7                        74.92

# %%
df2.T
# Out:
#                                        0          1          2          3   \
# SYMBOL \n                        NIFTY 50        TCS    HCLTECH      TECHM
# OPEN \n                         24,184.40   4,209.00   1,600.10   1,512.00
# HIGH \n                         24,196.50   4,306.20   1,629.75   1,529.45
# LOW \n                          24,099.70   4,188.15   1,598.25   1,505.00
# PREV. CLOSE \n                  24,139.00   4,196.95   1,592.65   1,503.40
# LTP \n                          24,143.75   4,293.00   1,623.90   1,525.45
# CHNG \n                              4.75      96.05      31.25      22.05
# %CHNG \n                             0.02       2.29       1.96       1.47
# VOLUME \n(shares)            30,32,54,705  32,26,545  39,32,148  28,33,790
# VALUE \n (₹ Crores)             27,834.44   1,376.36     634.84     430.93
# 52W H \n                        25,078.30   4,431.00   1,697.35   1,569.00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\etlProject\pythonProject\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CHNG'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df2['CHNG']
#
# ...

# %%
df2.sort_index[axis==1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df2.sort_index[axis==1]
#
# NameError: name 'axis' is not defined

# %%
df2.values[1][1]=100

# %%
df2
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1          TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2      HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3        TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4         INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5          M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6        WIPRO     493.00     496.85     490.45         490.50     495.70
# 7         BPCL     321.70     327.45     320.65         321.70     325.10
# 8   BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9   TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# 10        LTIM   5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# 11        SBIN     800.95     809.15     800.40         797.55     803.20
# ...

# %%
dfcopy=df2.copy()

# %%
dfcopy
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1          TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2      HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3        TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4         INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5          M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6        WIPRO     493.00     496.85     490.45         490.50     495.70
# 7         BPCL     321.70     327.45     320.65         321.70     325.10
# 8   BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9   TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# 10        LTIM   5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# 11        SBIN     800.95     809.15     800.40         797.55     803.20
# ...

# %%
df2
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1          TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2      HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3        TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4         INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5          M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6        WIPRO     493.00     496.85     490.45         490.50     495.70
# 7         BPCL     321.70     327.45     320.65         321.70     325.10
# 8   BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9   TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# 10        LTIM   5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# 11        SBIN     800.95     809.15     800.40         797.55     803.20
# ...

# %%
df2
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# 1          TCS   4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# 2      HCLTECH   1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# 3        TECHM   1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# 4         INFY   1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# 5          M&M   2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# 6        WIPRO     493.00     496.85     490.45         490.50     495.70
# 7         BPCL     321.70     327.45     320.65         321.70     325.10
# 8   BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# 9   TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# 10        LTIM   5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# 11        SBIN     800.95     809.15     800.40         797.55     803.20
# ...

# %%
df.dtypes(df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.dtypes(df2)
#
# TypeError: 'Series' object is not callable

# %%
df2.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df2.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df2.dtypes
# Out:
# SYMBOL \n                       object
# OPEN \n                         object
# HIGH \n                         object
# LOW \n                          object
# PREV. CLOSE \n                  object
# LTP \n                          object
# CHNG \n                        float64
# %CHNG \n                       float64
# VOLUME \n(shares)               object
# VALUE \n (₹ Crores)             object
# 52W H \n                        object
# 52W L \n                        object
# 30 D   %CHNG \n                float64
# 365 D % CHNG \n 14-Aug-2023    float64
# dtype: object

# %%
df2.shape
# Out:
# (51, 14)

# %%
df2.columns
# Out:
# Index(['SYMBOL \n', 'OPEN \n', 'HIGH \n', 'LOW \n', 'PREV. CLOSE \n', 'LTP \n',
#        'CHNG \n', '%CHNG \n', 'VOLUME \n(shares)', 'VALUE \n (₹ Crores)',
#        '52W H \n', '52W L \n', '30 D   %CHNG \n',
#        '365 D % CHNG \n 14-Aug-2023'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
df3=pd.read_csv('MW-NIFTY-50-15-Aug-2024.csv',index_col='SYMBOL \n')

# %%
df3
# Out:
#               OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# SYMBOL \n
# NIFTY 50    24,184.40  24,196.50  24,099.70      24,139.00  24,143.75
# TCS          4,209.00   4,306.20   4,188.15       4,196.95   4,293.00
# HCLTECH      1,600.10   1,629.75   1,598.25       1,592.65   1,623.90
# TECHM        1,512.00   1,529.45   1,505.00       1,503.40   1,525.45
# INFY         1,802.00   1,825.00   1,797.45       1,797.45   1,820.00
# M&M          2,728.80   2,771.95   2,715.30       2,718.05   2,749.45
# WIPRO          493.00     496.85     490.45         490.50     495.70
# BPCL           321.70     327.45     320.65         321.70     325.10
# BHARTIARTL   1,453.10   1,480.10   1,453.10       1,459.70   1,473.25
# TATAMOTORS   1,057.00   1,067.05   1,047.00       1,053.45   1,062.85
# LTIM         5,395.00   5,439.95   5,367.00       5,384.90   5,432.05
# SBIN           800.95     809.15     800.40         797.55     803.20
# ...

# %%
df3.dtypes
# Out:
# OPEN \n                         object
# HIGH \n                         object
# LOW \n                          object
# PREV. CLOSE \n                  object
# LTP \n                          object
# CHNG \n                        float64
# %CHNG \n                       float64
# VOLUME \n(shares)               object
# VALUE \n (₹ Crores)             object
# 52W H \n                        object
# 52W L \n                        object
# 30 D   %CHNG \n                float64
# 365 D % CHNG \n 14-Aug-2023    float64
# dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, NIFTY 50 to DIVISLAB
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   OPEN
#                       51 non-null     object
#  1   HIGH
#                       51 non-null     object
#  2   LOW
#                        51 non-null     object
#  3   PREV. CLOSE
#                51 non-null     object
#  4   LTP
#                        51 non-null     object
#  5   CHNG
#                       51 non-null     float64
#  6   %CHNG
#                      51 non-null     float64
#  7   VOLUME
# (shares)            51 non-null     object
#  8   VALUE
#  (₹ Crores)          51 non-null     object
#  9   52W H
#                      51 non-null     object
#  10  52W L
#                      51 non-null     object
#  11  30 D   %CHNG
#               51 non-null     float64
#  12  365 D % CHNG
# ...

# %%
df2.describe()
# Out:
#           CHNG \n   %CHNG \n  30 D   %CHNG \n  365 D % CHNG \n 14-Aug-2023
# count   51.000000  51.000000        51.000000                    51.000000
# mean   -14.301569  -0.328235        -1.406863                    31.196471
# std     59.930061   1.300781         5.616498                    34.142106
# min   -264.650000  -4.030000       -12.350000                   -88.700000
# 25%    -14.750000  -1.025000        -5.100000                    12.180000
# 50%     -2.380000  -0.170000        -0.880000                    25.770000
# 75%      6.000000   0.505000         2.570000                    40.320000
# max     96.050000   2.290000         9.800000                   115.780000

# %%
df4=pd.read_excel('employee data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\PycharmProjects\etlProject\pythonProject\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File C:\ETLPython\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...
